# %% [markdown]
# This script is used to read the raw data and generate `education.csv`.

# %%
import pandas as pd
import numpy as np

from constants import HEALTH_DIMENSION_CSV

# %%
df = pd.read_csv('../raw_data/health.csv')
df.replace("..", np.nan, inplace=True)

# %%
columns = df.columns.tolist()
# fix column years format
for i in range(4, len(columns)):
	columns[i] = columns[i][:4]
df.columns = columns
df.head(6)
# Out:
#                              Series Name        Series Code   Country Name  \
# 0  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS        Nigeria
# 1  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS         Canada
# 2  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS  United States
# 3  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS         Mexico
# 4  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS          India
# 5  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS      Indonesia
#
#   Country Code        2005        2006        2007        2008        2009  \
# 0          NGA         NaN  0.14318085  0.12165572  0.11850549  0.12064154
# 1          CAN   0.4640432  0.48383656  0.61307919  0.47915494  0.54793304
# 2          USA  0.65363973  0.66477114    0.717116  0.76118088  0.70491374
# 3          MEX  0.12093282  0.11649629  0.09540497  0.12782037  0.22113964
# 4          IND  0.16114938  0.18146034  0.18110792  0.17476563   0.1732502
# 5          IDN  0.19221886  0.74896973  1.14058006   1.5462302  0.35963088
#
#          2010        2011        2012        2013        2014        2015  \
# 0  0.22609136  0.33519816  0.17587431  0.24704842  0.13496079  0.03564164
# 1  0.58610934  0.55770832  0.55659932  0.48322916  0.43591252  0.45552984
# 2  0.68704522   0.7024169  0.70865661  0.69361621  0.64768839  0.64494258
# 3  0.19516744  0.11883423   0.1054229  0.08809453   0.0933276  0.07663224
# 4  0.17793332  0.19404872  0.19756314  0.28407836   0.2564413  0.24175881
# 5  0.09928948  0.10745579  0.11114662  0.14210127  0.10707583  0.18466645
#
#          2016        2017        2018        2019 2020
# 0  0.18983622  0.13156208  0.26808563  0.13931434  NaN
# 1     0.42354  0.38220248  0.38234833  0.39864108  NaN
# 2  0.63860589  0.67145181  0.66255105  0.67703497  NaN
# 3  0.08285465  0.07024645  0.08476871  0.06373785  NaN
# 4  0.27061391         NaN         NaN         NaN  NaN
# 5  0.19835544  0.21494839  0.19273698  0.19167218  NaN

# %%
# Replace missing value with the mean value for each country and attribute 
df[columns[4:]] = df[columns[4:]].T.fillna(df.mean(axis=1)).T
df.head(6)
# Out:
# C:\Users\honyl\AppData\Local\Temp\ipykernel_10492\3330549296.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[columns[4:]] = df[columns[4:]].T.fillna(df.mean(axis=1)).T
#                              Series Name        Series Code   Country Name  \
# 0  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS        Nigeria
# 1  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS         Canada
# 2  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS  United States
# 3  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS         Mexico
# 4  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS          India
# 5  Capital health expenditure (% of GDP)  SH.XPD.KHEX.GD.ZS      Indonesia
#
#   Country Code        2005        2006        2007        2008        2009  \
# 0          NGA         NaN  0.14318085  0.12165572  0.11850549  0.12064154
# 1          CAN   0.4640432  0.48383656  0.61307919  0.47915494  0.54793304
# 2          USA  0.65363973  0.66477114    0.717116  0.76118088  0.70491374
# 3          MEX  0.12093282  0.11649629  0.09540497  0.12782037  0.22113964
# 4          IND  0.16114938  0.18146034  0.18110792  0.17476563   0.1732502
# 5          IDN  0.19221886  0.74896973  1.14058006   1.5462302  0.35963088
#
#          2010        2011        2012        2013        2014        2015  \
# 0  0.22609136  0.33519816  0.17587431  0.24704842  0.13496079  0.03564164
# 1  0.58610934  0.55770832  0.55659932  0.48322916  0.43591252  0.45552984
# 2  0.68704522   0.7024169  0.70865661  0.69361621  0.64768839  0.64494258
# 3  0.19516744  0.11883423   0.1054229  0.08809453   0.0933276  0.07663224
# 4  0.17793332  0.19404872  0.19756314  0.28407836   0.2564413  0.24175881
# 5  0.09928948  0.10745579  0.11114662  0.14210127  0.10707583  0.18466645
#
#          2016        2017        2018        2019 2020
# 0  0.18983622  0.13156208  0.26808563  0.13931434  NaN
# 1     0.42354  0.38220248  0.38234833  0.39864108  NaN
# 2  0.63860589  0.67145181  0.66255105  0.67703497  NaN
# 3  0.08285465  0.07024645  0.08476871  0.06373785  NaN
# 4  0.27061391         NaN         NaN         NaN  NaN
# 5  0.19835544  0.21494839  0.19273698  0.19167218  NaN

# %%
attributes_dic = {
    "capital_health_expenditure_percent_of_gdp": "SH.XPD.KHEX.GD.ZS",
    "current_health_expenditure_percent_of_gdp": "SH.XPD.CHEX.GD.ZS",
    "government_health_expenditure_percent_of_gdp": "SH.XPD.GHED.GD.ZS",
    "community_health_workers_per_1000": "SH.MED.CMHW.P3",
    "prevalence_of_hiv": "SH.DYN.AIDS.ZS",
    "prevalence_of_hiv_male": "SH.HIV.1524.MA.ZS",
    "prevalence_of_hiv_female": "SH.HIV.1524.FE.ZS",
    "adults_with_hiv": "SH.DYN.AIDS",
    "children_with_hiv": "SH.HIV.0014",
    "prevalence_of_overweight_adult": "SH.STA.OWAD.ZS",
    "prevalence_of_overweight_children_under_5": "SH.STA.OWGH.ZS",
    "prevalence_of_severe_wasting_children_under_5": "SH.SVR.WAST.ZS",
    "prevalence_of_stunting_children_under_5": "SH.STA.STNT.ZS",
    "prevalence_of_undernourishment": "SN.ITK.DEFC.ZS",
    "hospital_beds_per_1000": "SH.MED.BEDS.ZS",
    "physicians_per_1000": "SH.MED.PHYS.ZS",
    "number_of_stillbirths": "SH.DTH.STLB",
}

# %%
def transpose_attributes(dataframe, attribute):
	dataframe.drop(columns=["Series Name", "Series Code", "Country Name"], inplace=True)
	columns = dataframe.columns.tolist()
	return dataframe.melt(id_vars="Country Code", value_vars=columns[1:], var_name="Year", value_name=attribute)

# %%
# Transpose Attributes
attributes_df_dic = {}
for key, value in attributes_dic.items(): 
	filt = (df["Series Code"] == value)
	attribute_df = df.loc[filt].copy()
	attributes_df_dic[key] = transpose_attributes(attribute_df, key)

# %%
# Merge attributes together
attributes_lst_dic = list(attributes_df_dic.values())
health_df = attributes_lst_dic[0] 
for i in range(1, len(attributes_lst_dic)):
	health_df = pd.merge(health_df, attributes_lst_dic[i], how="left", left_on=["Country Code", "Year"], right_on=["Country Code", "Year"])
health_df.rename_axis("health_key", inplace=True)
health_df.head(30)
# Out:
#            Country Code  Year capital_health_expenditure_percent_of_gdp  \
# health_key
# 0                   NGA  2005                                       NaN
# 1                   CAN  2005                                 0.4640432
# 2                   USA  2005                                0.65363973
# 3                   MEX  2005                                0.12093282
# 4                   IND  2005                                0.16114938
# 5                   IDN  2005                                0.19221886
# 6                   IRN  2005                                0.11898085
# 7                   EGY  2005                                       NaN
# 8                   KEN  2005                                       NaN
# 9                   NGA  2006                                0.14318085
# 10                  CAN  2006                                0.48383656
# 11                  USA  2006                                0.66477114
# 12                  MEX  2006                                0.11649629
# 13                  IND  2006                                0.18146034
# 14                  IDN  2006                                0.74896973
# 15                  IRN  2006                                0.14640558
# 16                  EGY  2006                                       NaN
# 17                  KEN  2006                                       NaN
# 18                  NGA  2007                                0.12165572
# 19                  CAN  2007                                0.61307919
# 20                  USA  2007                                  0.717116
# 21                  MEX  2007                                0.09540497
# 22                  IND  2007                                0.18110792
# 23                  IDN  2007                                1.14058006
# 24                  IRN  2007                                0.14948277
# 25                  EGY  2007                                       NaN
# 26                  KEN  2007                                       NaN
# 27                  NGA  2008                                0.11850549
# 28                  CAN  2008                                0.47915494
# 29                  USA  2008                                0.76118088
#
#            current_health_expenditure_percent_of_gdp  \
# health_key
# 0                                         4.46591902
# 1                                         9.03540611
# 2                                        14.60504532
# 3                                         5.83612156
# 4                                         3.79116249
# 5                                         2.53189397
# 6                                         5.38635683
# 7                                         4.92229176
# 8                                         5.31436443
# 9                                         4.25775146
# 10                                        9.34210205
# 11                                       14.71834183
# 12                                        5.65525532
# 13                                        3.63477802
# 14                                         2.6194644
# 15                                        5.29366922
# 16                                        4.84190083
# 17                                        5.87344933
# 18                                        3.90997314
# 19                                        9.44500446
# 20                                       14.93882084
# 21                                        5.76644516
# 22                                        3.51754165
# 23                                        2.82385564
# 24                                        5.06425858
# 25                                        4.44493246
# 26                                        5.99706697
# 27                                         3.6958158
# 28                                        9.60709858
# 29                                        15.2670145
#
#            government_health_expenditure_percent_of_gdp  \
# health_key
# 0                                            1.14133215
# 1                                            6.59905815
# 2                                            6.62940884
# 3                                            2.46497631
# 4                                            0.76303685
# 5                                            0.73213077
# 6                                            1.98597813
# 7                                             1.5893116
# 8                                            1.48269117
# 9                                            0.90186709
# 10                                            6.4866991
# 11                                           6.80890989
# 12                                            2.4219811
# 13                                            0.7453534
# 14                                           0.83084285
# 15                                           2.20625329
# 16                                           1.74427295
# 17                                           1.45845628
# 18                                           0.77861226
# 19                                           6.57271051
# 20                                            6.9233551
# 21                                           2.52675962
# 22                                           0.73512703
# 23                                           1.01869869
# 24                                           2.01693583
# 25                                           1.56855941
# 26                                           1.55638492
# 27                                           0.66059947
# 28                                           6.70117044
# 29                                           7.25172758
#
#            community_health_workers_per_1000 prevalence_of_hiv  \
# health_key
# 0                                        NaN               1.5
# 1                                        NaN               NaN
# 2                                        NaN               NaN
# 3                                        NaN               0.3
# 4                                      0.627               NaN
# 5                                        NaN               0.2
# 6                                        NaN               0.1
# 7                                        NaN               0.1
# 8                                        NaN               6.8
# 9                                        NaN               1.5
# 10                                       NaN               NaN
# 11                                       NaN               NaN
# 12                                       NaN               0.3
# 13                                     0.614               NaN
# 14                                       NaN               0.2
# 15                                       NaN               0.1
# 16                                       NaN               0.1
# 17                                       NaN               6.4
# 18                                     0.131               1.4
# 19                                       NaN               NaN
# 20                                       NaN               NaN
# 21                                       NaN               0.3
# 22                                     0.614               NaN
# 23                                       NaN               0.2
# 24                                       NaN               0.1
# 25                                       NaN               0.1
# 26                                       NaN               6.2
# 27                                     0.128               1.4
# 28                                       NaN               NaN
# 29                                       NaN               NaN
#
#            prevalence_of_hiv_male prevalence_of_hiv_female adults_with_hiv  \
# health_key
# 0                             0.4                      0.8         1100000
# 1                             NaN                      NaN             NaN
# 2                             NaN                      NaN             NaN
# 3                             0.1                      0.1          190000
# 4                             NaN                      NaN             NaN
# 5                             0.2                      0.1          200000
# 6                             0.1                      0.1           54000
# 7                             0.1                      0.1            2300
# 8                             1.3                      3.8         1200000
# 9                             0.4                      0.8         1100000
# 10                            NaN                      NaN             NaN
# 11                            NaN                      NaN             NaN
# 12                            0.1                      0.1          190000
# 13                            NaN                      NaN             NaN
# 14                            0.3                      0.1          240000
# 15                            0.1                      0.1           61000
# 16                            0.1                      0.1            2700
# 17                            1.3                      3.6         1200000
# 18                            0.4                      0.7         1200000
# 19                            NaN                      NaN             NaN
# 20                            NaN                      NaN             NaN
# 21                            0.1                      0.1          200000
# 22                            NaN                      NaN             NaN
# 23                            0.3                      0.1          280000
# 24                            0.1                      0.1           66000
# 25                            0.1                      0.1            3200
# 26                            1.3                      3.5         1200000
# 27                            0.4                      0.7         1200000
# 28                            NaN                      NaN             NaN
# 29                            NaN                      NaN             NaN
#
#            children_with_hiv prevalence_of_overweight_adult  \
# health_key
# 0                     140000                           21.8
# 1                        NaN                           58.6
# 2                        NaN                           61.9
# 3                       1900                           58.9
# 4                        NaN                           14.2
# 5                       2700                           19.8
# 6                        500                           53.4
# 7                        100                           56.3
# 8                     230000                           19.5
# 9                     150000                           22.4
# 10                       NaN                           59.2
# 11                       NaN                           62.5
# 12                      2200                           59.5
# 13                       NaN                           14.6
# 14                      3600                           20.5
# 15                       500                           54.2
# 16                       100                           56.9
# 17                    220000                             20
# 18                    150000                             23
# 19                       NaN                           59.7
# 20                       NaN                           63.1
# 21                      2400                           60.1
# 22                       NaN                           15.1
# 23                      4500                           21.2
# 24                       530                             55
# 25                       100                           57.6
# 26                    220000                           20.5
# 27                    150000                           23.7
# 28                       NaN                           60.2
# 29                       NaN                           63.7
#
#            prevalence_of_overweight_children_under_5  \
# health_key
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                               14.1
# 8                                                7.9
# 9                                                NaN
# 10                                               NaN
# 11                                                 8
# 12                                               7.5
# 13                                               1.9
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                              11.2
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               7.4
#
#            prevalence_of_severe_wasting_children_under_5  \
# health_key
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    2.5
# 8                                                    2.4
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   0.2
# 12                                                   0.4
# 13                                                   6.8
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   6.8
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   0.1
#
#            prevalence_of_stunting_children_under_5  \
# health_key
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                             23.9
# 8                                             40.3
# 9                                              NaN
# 10                                             NaN
# 11                                             3.1
# 12                                            15.5
# 13                                            47.8
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                            40.1
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             2.3
#
#            prevalence_of_undernourishment hospital_beds_per_1000  \
# health_key
# 0                                     7.1                    NaN
# 1                                     2.5                    3.1
# 2                                     2.5                    3.2
# 3                                     4.4                   1.05
# 4                                    21.6                   0.41
# 5                                    19.2                    NaN
# 6                                     5.2                   1.72
# 7                                     6.4                    2.2
# 8                                    28.5                    NaN
# 9                                     6.7                    NaN
# 10                                    2.5                   3.02
# 11                                    2.5                   3.18
# 12                                    4.1                   1.02
# 13                                   19.6                   0.42
# 14                                     19                    NaN
# 15                                    5.5                   1.72
# 16                                      6                    2.2
# 17                                   26.1                    1.4
# 18                                    6.6                    NaN
# 19                                    2.5                   2.96
# 20                                    2.5                   3.14
# 21                                    4.1                   1.06
# 22                                   17.5                   0.41
# 23                                   18.5                    NaN
# 24                                    5.7                   1.72
# 25                                    5.7                    2.1
# 26                                   26.9                    NaN
# 27                                    6.8                    NaN
# 28                                    2.5                   2.85
# 29                                    2.5                   3.13
#
#            physicians_per_1000 number_of_stillbirths
# health_key
# 0                       0.2824                154544
# 1                          NaN                  1037
# 2                          NaN                 12382
# 3                       3.5303                 18512
# 4                       0.5885                734078
# 5                          NaN                 66751
# 6                       0.8869                 12218
# 7                          NaN                 28256
# 8                          NaN                 32030
# 9                       0.3481                155634
# 10                      1.9086                  1083
# 11                         NaN                 12336
# 12                       3.762                 18000
# 13                      0.6012                699284
# 14                         NaN                 65867
# 15                      0.5361                 12069
# 16                         NaN                 28063
# 17                         NaN                 32204
# 18                      0.3784                156405
# 19                         NaN                  1129
# 20                         NaN                 12454
# 21                       3.843                 17560
# 22                      0.6182                659445
# 23                         NaN                 64869
# 24                         NaN                 11914
# 25                         NaN                 27912
# 26                         NaN                 32210
# 27                      0.3762                157292
# 28                       1.959                  1138
# 29                         NaN                 12805

# %%
# Output Education Dimension
health_df.to_csv(HEALTH_DIMENSION_CSV)
