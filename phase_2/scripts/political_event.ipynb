# %%
import pandas as pd
import numpy as np

from constants import POLITICAL_EVENT_DIMENSION_CSV

# %%
df = pd.read_csv('../raw_data/political_events.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
countries = ["Canada", "USA", "Mexico", "India", "Indonesia", "Iran", "Egypt", "Kenya", "Nigeria"]
year = 2005
filter = (df["countryname"].isin(countries)) & (df["year"] >= year)
political_event_df = df.loc[filter].copy()
political_event_df.reset_index(inplace=True)
political_event_df.rename_axis("political_event_key", inplace=True)
political_event_df.head(8)
# Out:
#                      index countryname  ifs    year  system  yrsoffc  \
# political_event_key
# 0                     1234      Canada  CAN  2005.0     2.0      3.0
# 1                     1235      Canada  CAN  2006.0     2.0      4.0
# 2                     1236      Canada  CAN  2007.0     2.0      1.0
# 3                     1237      Canada  CAN  2008.0     2.0      2.0
# 4                     1238      Canada  CAN  2009.0     2.0      3.0
# 5                     1239      Canada  CAN  2010.0     2.0      4.0
# 6                     1240      Canada  CAN  2011.0     2.0      5.0
# 7                     1241      Canada  CAN  2012.0     2.0      6.0
#
#                      finittrm  yrcurnt  multpl  military  ...  dhondt     cl  \
# political_event_key                                       ...
# 0                         1.0      3.0     1.0       0.0  ...  -999.0 -999.0
# 1                         1.0      2.0     1.0       0.0  ...  -999.0 -999.0
# ...

# %%
columns_rename_dic = {
	"ifs": "Country Code",
	"year": "Year",
}
columns_to_drop = ["index", "countryname"]

political_event_df.rename(columns=columns_rename_dic, inplace=True)
political_event_df.drop(columns=columns_to_drop, inplace=True)
political_event_df.head(14)
# Out:
#                     Country Code    Year  system  yrsoffc  finittrm  yrcurnt  \
# political_event_key
# 0                            CAN  2005.0     2.0      3.0       1.0      3.0
# 1                            CAN  2006.0     2.0      4.0       1.0      2.0
# 2                            CAN  2007.0     2.0      1.0       1.0      3.0
# 3                            CAN  2008.0     2.0      2.0       1.0      2.0
# 4                            CAN  2009.0     2.0      3.0       1.0      3.0
# 5                            CAN  2010.0     2.0      4.0       1.0      2.0
# 6                            CAN  2011.0     2.0      5.0       1.0      1.0
# 7                            CAN  2012.0     2.0      6.0       1.0      3.0
# 8                            CAN  2013.0     2.0      7.0       1.0      2.0
# 9                            CAN  2014.0     2.0      8.0       1.0      1.0
# 10                           CAN  2015.0     2.0      9.0       1.0      0.0
# ...

# %%
political_event_df.to_csv(POLITICAL_EVENT_DIMENSION_CSV)
