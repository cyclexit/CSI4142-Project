# %% [markdown]
# ### Classification (Supervised Learning)
#
# **Human Development Index (HDI)** is between 0.0 and 1.0 inclusively, so if we directly use those values to train the model and try to predict the HDI in 2020 for the 9 countries, this problem will become a regression problem. Hence, we mask the HDI to 4 levels according to https://worldpopulationreview.com/country-rankings/hdi-by-country:
# * very high (0.8-1.0), masked as 0
# * high (0.7-0.79), masked as 1
# * medium (0.55-0.70), masked as 2
# * low (< 0.55), masked as 3

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
LABEL = "human_development_index"
static_fields = [LABEL, "year_num", "country_name"]

# %%
def mask_hdi(label: pd.DataFrame):
    for _, row in label.iterrows():
        if 0.8 <= row[LABEL] and row[LABEL] <= 1.0:
            row[LABEL] = 0
        elif 0.7 <= row[LABEL] and row[LABEL] < 0.8:
            row[LABEL] = 1
        elif 0.55 <= row[LABEL] and row[LABEL] < 0.7:
            row[LABEL] = 2
        else:
            row[LABEL] = 3

# %%
train_set = pd.read_csv("../data_imputed/train.csv")
train_data = train_set.drop(columns=static_fields)
train_label = train_set[[LABEL]] # HDI
mask_hdi(train_label)
train_label = train_label.astype(int)
train_data
# Out:
#      secondary_school_enrollment_percent_of_gross  life_expectancy_female  \
# 0                                        1.127325                1.159917
# 1                                        0.821231                0.885589
# 2                                        0.205614                0.655043
# 3                                       -1.162674               -0.732180
# 4                                       -0.863992               -0.320688
# ..                                            ...                     ...
# 130                                      0.415835                0.212607
# 131                                      0.357700                0.642534
# 132                                      0.552170                0.254634
# 133                                     -1.258836               -0.327052
# 134                                     -1.507657               -1.800744
#
#      life_expectancy_male  tertiary_school_enrollment_percent_of_gross  \
# 0                1.165150                                     1.004027
# 1                0.816180                                     1.687073
# 2                0.524369                                    -0.512046
# 3               -0.544924                                    -1.039692
# 4               -0.317491                                    -0.784512
# ..                    ...                                          ...
# 130              0.163004                                    -0.201701
# 131              0.887538                                     0.898119
# 132              0.183461                                    -0.135710
# 133             -0.469835                                    -1.064687
# 134             -1.736235                                    -0.894304
#
#      government_health_expenditure_percent_of_gdp  birth_rate  \
# 0                                        1.390093   -1.305304
# 1                                        1.401717   -0.932006
# 2                                       -0.193247   -0.082093
# 3                                       -0.845085    0.175483
# 4                                       -0.856922   -0.079458
# ..                                            ...         ...
# 130                                     -0.592866   -0.520719
# 131                                      0.134995   -0.446718
# 132                                     -0.632924    0.353458
# 133                                     -0.328713    0.637824
# 134                                     -0.952472    1.642216
#
#      hospital_beds_per_1000  prevalence_of_overweight_adult  fertility_rate  \
# 0                  1.925774                        0.704147       -1.046742
# 1                  2.043557                        0.874690       -0.639155
# 2                 -0.488784                        0.719651       -0.291563
# 3                 -1.242598                       -1.590422        0.086978
# 4                 -1.077701                       -1.301017       -0.276485
# ..                      ...                             ...             ...
# 130               -0.514697                        0.485026       -0.455836
# 131                0.102488                        0.756860       -0.568525
# 132                0.481750                        0.766163        0.331404
# 133               -0.646614                       -1.067425        0.444887
# 134               -0.780887                       -0.898950        1.947943
#
#      growth_rate  current_health_expenditure_percent_of_gdp  \
# 0      -0.955096                                   0.620098
# 1      -0.990006                                   2.006198
# 2      -0.231936                                  -0.176099
# 3       0.019513                                  -0.685022
# 4      -0.353926                                  -0.998413
# ..           ...                                        ...
# 130    -0.719654                                  -0.905575
# 131    -0.329402                                   0.041534
# 132     0.627945                                  -0.448894
# 133     1.082792                                  -0.485763
# 134     1.530981                                  -0.875281
#
#      basic_drinking_water_rate_rural  basic_drinking_water_rate  \
# 0                           0.856394                   0.775509
# 1                           0.717585                   0.750988
# 2                           0.011330                   0.380427
# 3                          -0.127010                  -0.260867
# 4                          -0.567814                  -0.461140
# ..                               ...                        ...
# 130                         0.157152                   0.287133
# 131                         0.613724                   0.654499
# 132                         0.909792                   0.785073
# 133                        -1.571499                  -1.688471
# 134                        -1.111686                  -0.730406
#
#      prevalence_of_undernourishment  open_defecation_rate  \
# 0                         -0.915383             -0.764583
# 1                         -0.915383             -0.764583
# 2                         -0.647064             -0.235156
# 3                          1.781928              3.743687
# 4                          1.442999              1.171635
# ..                              ...                   ...
# 130                       -0.350501             -0.207915
# 131                       -0.491722             -0.737956
# 132                       -0.505844             -0.764583
# 133                        2.233833             -0.079150
# 134                        0.793385              0.695094
#
#      open_defecation_rate_rural  open_defecation_rate_urban  \
# 0                     -0.841343                   -0.727362
# 1                     -0.841343                   -0.727362
# 2                      0.310192                   -0.131227
# 3                      3.476385                    3.493500
# 4                      1.303083                    1.626866
# ..                          ...                         ...
# 130                   -0.097242                   -0.134797
# 131                   -0.769504                   -0.727362
# 132                   -0.841343                   -0.727362
# 133                   -0.159386                   -0.436158
# 134                    0.883448                    1.088371
#
#      prevalence_of_hiv  capital_health_expenditure_percent_of_gdp
# 0            -0.324478                                   0.636980
# 1            -0.299879                                   1.446801
# 2            -0.410573                                  -0.828543
# 3            -0.459770                                  -0.656766
# 4            -0.472069                                  -0.524060
# ..                 ...                                        ...
# 130          -0.349076                                  -0.526395
# 131          -0.533565                                  -0.310573
# 132          -0.533565                                  -0.711165
# 133           2.110772                                   0.866546
# 134           0.204389                                  -0.750030
#
# [135 rows x 19 columns]

# %%
model_dt = DecisionTreeClassifier()
model_gb = GradientBoostingClassifier()
model_rf = RandomForestClassifier()
